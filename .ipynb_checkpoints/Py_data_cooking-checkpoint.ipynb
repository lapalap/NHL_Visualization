# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np

# %%
PlayerInf = pd.read_csv("../data/player_info.csv")
#Games_plays = pd.read_csv("../data/game_plays.csv")

#Game_goalie_stats = pd.read_csv("../data/game_plays_players.csv")
Game_skater_stats = pd.read_csv("../data/game_skater_stats.csv")
Game = pd.read_csv("../data/game.csv")

# %% [markdown]
# ### Players Statistics (detailed)

# %%
Player_stat_detailed = pd.merge(Game_skater_stats, Game, on='game_id')

# %%
Player_stat_detailed.columns
# Out:
# Index(['game_id', 'player_id', 'team_id', 'timeOnIce', 'assists', 'goals',
#        'shots', 'hits', 'powerPlayGoals', 'powerPlayAssists', 'penaltyMinutes',
#        'faceOffWins', 'faceoffTaken', 'takeaways', 'giveaways',
#        'shortHandedGoals', 'shortHandedAssists', 'blocked', 'plusMinus',
#        'evenTimeOnIce', 'shortHandedTimeOnIce', 'powerPlayTimeOnIce', 'season',
#        'type', 'date_time', 'away_team_id', 'home_team_id', 'away_goals',
#        'home_goals', 'outcome', 'home_rink_side_start', 'venue', 'venue_link',
#        'venue_time_zone_id', 'venue_time_zone_offset', 'venue_time_zone_tz'],
#       dtype='object')

# %%
Player_stat_detailed = Player_stat_detailed.drop(['game_id', 'team_id', 'type', 'date_time', 'away_team_id', 'home_team_id', 'away_goals',
       'home_goals', 'outcome', 'home_rink_side_start', 'venue', 'venue_link',
       'venue_time_zone_id', 'venue_time_zone_offset', 'venue_time_zone_tz' ], axis=1)

# %%
Player_stat_detailed['count'] = 1

# %%
Player_stat_detailed.columns
# Out:
# Index(['player_id', 'timeOnIce', 'assists', 'goals', 'shots', 'hits',
#        'powerPlayGoals', 'powerPlayAssists', 'penaltyMinutes', 'faceOffWins',
#        'faceoffTaken', 'takeaways', 'giveaways', 'shortHandedGoals',
#        'shortHandedAssists', 'blocked', 'plusMinus', 'evenTimeOnIce',
#        'shortHandedTimeOnIce', 'powerPlayTimeOnIce', 'season', 'count'],
#       dtype='object')

# %%
grouped = Player_stat_detailed.groupby('player_id', as_index = False)

# %%
Player_stat_detailed = grouped.agg({'timeOnIce' : 'mean',
                                     'assists' : 'mean',
                                     'goals' : 'mean',
                                     'shots' : 'mean',
                                     'hits' : 'mean',
                                     'powerPlayGoals' : 'mean',
                                     'powerPlayAssists' : 'mean',
                                     'penaltyMinutes' : 'mean',
                                     'faceOffWins' : 'mean',
                                     'faceoffTaken' : 'mean',
                                     'takeaways' : 'mean',
                                     'giveaways' : 'mean',
                                     'shortHandedGoals' : 'mean',
                                     'shortHandedAssists' : 'mean',
                                     'blocked' : 'mean',
                                     'plusMinus' : 'sum',
                                     'evenTimeOnIce' : 'mean',
                                     'shortHandedTimeOnIce' : 'mean',
                                     'powerPlayTimeOnIce' : 'mean',
                                     'count' : 'sum'}, group_keys = True)

# %%
Player_stat_detailed = pd.merge(Player_stat_detailed, PlayerInf, on='player_id')
Player_stat_detailed.columns
# Out:
# Index(['player_id', 'timeOnIce', 'assists', 'goals', 'shots', 'hits',
#        'powerPlayGoals', 'powerPlayAssists', 'penaltyMinutes', 'faceOffWins',
#        'faceoffTaken', 'takeaways', 'giveaways', 'shortHandedGoals',
#        'shortHandedAssists', 'blocked', 'plusMinus', 'evenTimeOnIce',
#        'shortHandedTimeOnIce', 'powerPlayTimeOnIce', 'count', 'firstName',
#        'lastName', 'nationality', 'birthCity', 'primaryPosition', 'birthDate',
#        'link'],
#       dtype='object')

# %%
import seaborn as sns
# %matplotlib inline

sns.distplot(Player_stat_detailed['plusMinus'], rug=True)
# Out:
# /Users/kirillbykov/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Player_stat_detailed[['goals','firstName',
       'lastName', 'nationality', 'birthCity', 'primaryPosition', 'birthDate',
       'link']].sort_values(by=['goals'])
# Out:
#          goals firstName    lastName nationality      birthCity  \
# 790   0.000000    Joonas    Nattinen         FIN          Jamsa
# 935   0.000000    Julian   Melchiori         CAN  Richmond Hill
# 928   0.000000    Jarred     Tinordi         USA     Burnsville
# 917   0.000000    Morgan       Ellis         CAN     Summerside
# 914   0.000000    Petter    Granberg         SWE      Gallivare
# 899   0.000000     Brett      Bulmer         CAN  Prince George
# 898   0.000000      John   McFarland         CAN  Richmond Hill
# 884   0.000000    Curtis    Hamilton         USA         Tacoma
# 882   0.000000     Danny       Biega         CAN       Montreal
# 880   0.000000      Mark         Alt         USA    Kansas City
# 876   0.000000      Petr      Straka         CZE          Plzen
# 865   0.000000     Chris       Breen         CAN       Uxbridge
# 854   0.000000    Andrew    Agozzino         CAN      Kleinburg
# 852   0.000000      Mike     Liambas         CAN        Toronto
# 848   0.000000    Justin     Dowling         CAN        Calgary
# 847   0.000000   Matthew       Konan         USA         Orange
# 843   0.000000       Ben      Sexton         CAN         Ottawa
# 835   0.000000     Scott     Timmins         CAN       Hamilton
# 751   0.000000    Carter      Ashton         CAN       Winnipeg
# 758   0.000000       Mat       Clark         USA    Wheat Ridge
# 778   0.000000     Louis     Leblanc         CAN  Pointe-Claire
# 783   0.000000     Jamie      Devane         CAN    Mississauga
# 787   0.000000    Philip  Samuelsson         SWE        Leksand
# 1579  0.000000      Eric    Robinson         USA       BELLMAWR
# 938   0.000000    Justin       Shugg         CAN  Niagara Falls
# 793   0.000000     Jesse     Blacker         CAN        Toronto
# 812   0.000000      Ryan     Bourque         USA        Boxford
# 817   0.000000   Garrett      Wilson         CAN         Barrie
# 825   0.000000   Patrick         Wey         USA     Pittsburgh
# 830   0.000000   Garrett    Mitchell         CAN         Regina
# ...        ...       ...         ...         ...            ...
# 1386  0.375000     David    Pastrnak         CZE        Havirov
# 281   0.376847      Zach      Parise         USA    Minneapolis
# 621   0.378378   Evgenii     Dadonov         RUS    Chelyabinsk
# 277   0.380952      Jeff      Carter         CAN         London
# 1259  0.383648      Jake    Guentzel         USA          Omaha
# 488   0.386694      Brad    Marchand         CAN        Halifax
# 624   0.396104       Max  Pacioretty         USA     New Canaan
# 320   0.401942       Joe    Pavelski         USA         Plover
# 925   0.411638     Tyler      Seguin         CAN       Brampton
# 1074  0.412178    Nikita    Kucherov         RUS         Maykop
# 1439  0.414414    Connor     McDavid         CAN  Richmond Hill
# 568   0.415948     Jamie        Benn         CAN       Victoria
# 412   0.423372    Sidney      Crosby         CAN   Cole Harbour
# 340   0.429530    Evgeni      Malkin         RUS   Magnitogorsk
# 907   0.430108  Vladimir   Tarasenko         RUS      Yaroslavl
# 619   0.432866   Patrick        Kane         USA        Buffalo
# 762   0.442222      John     Tavares         CAN    Mississauga
# 1456  0.464789     Brock      Boeser         USA     Burnsville
# 652   0.478036    Steven     Stamkos         CAN        Markham
# 1520  0.494186    Patrik       Laine         FIN        Tampere
# 1343  0.500000      Matt       Carey         CAN       Hamilton
# 1576  0.500000   Spencer         Foo         CAN     St. Albert
# 844   0.500000      Adam    Almquist         SWE      Jönköping
# 1517  0.503185    Auston    Matthews         USA      San Ramon
# 339   0.575000      Alex    Ovechkin         RUS         Moscow
# 1403  1.000000    Warren     Foegele         CAN        Markham
# 1105  1.000000    Samuel      Henley         CAN       Val-d'Or
# 1502  1.000000      Sami        Niku         FIN      Haapavesi
# 874   1.000000    Justin        Holl         USA      Tonka Bay
# 1166  1.000000   Patrick     Sieloff         USA      Ann Arbor
#
#      primaryPosition   birthDate                    link
# 790                C  1991-01-03  /api/v1/people/8475198
# 935                D  1991-12-06  /api/v1/people/8475815
# 928                D  1992-02-20  /api/v1/people/8475797
# 917                D  1992-04-30  /api/v1/people/8475782
# 914                D  1992-08-27  /api/v1/people/8475774
# 899               RW  1992-04-26  /api/v1/people/8475757
# 898               LW  1992-04-02  /api/v1/people/8475756
# 884               LW  1991-12-04  /api/v1/people/8475734
# 882                D  1991-09-29  /api/v1/people/8475732
# 880                D  1991-10-18  /api/v1/people/8475729
# 876               RW  1992-06-15  /api/v1/people/8475723
# 865                D  1989-06-29  /api/v1/people/8475648
# 854               LW  1991-01-03  /api/v1/people/8475461
# 852               LW  1989-02-16  /api/v1/people/8475436
# 848                C  1990-10-01  /api/v1/people/8475413
# 847                D  1991-09-03  /api/v1/people/8475395
# 843                C  1991-06-06  /api/v1/people/8475328
# 835                C  1989-09-11  /api/v1/people/8475304
# 751               RW  1991-04-01  /api/v1/people/8475154
# 758                D  1990-10-17  /api/v1/people/8475162
# 778                C  1991-01-26  /api/v1/people/8475183
# 783               LW  1991-02-20  /api/v1/people/8475190
# 787                D  1991-07-26  /api/v1/people/8475194
# 1579              LW  1995-06-14  /api/v1/people/8480762
# 938               RW  1991-12-24  /api/v1/people/8475826
# 793                D  1991-04-19  /api/v1/people/8475203
# 812                C  1991-01-03  /api/v1/people/8475243
# 817               LW  1991-03-16  /api/v1/people/8475253
# 825                D  1991-03-21  /api/v1/people/8475275
# 830               RW  1991-09-02  /api/v1/people/8475291
# ...              ...         ...                     ...
# 1386              RW  1996-05-25  /api/v1/people/8477956
# 281               LW  1984-07-28  /api/v1/people/8470610
# 621               RW  1989-03-12  /api/v1/people/8474149
# 277                C  1985-01-01  /api/v1/people/8470604
# 1259               C  1994-10-06  /api/v1/people/8477404
# 488               LW  1988-05-11  /api/v1/people/8473419
# 624               LW  1988-11-20  /api/v1/people/8474157
# 320                C  1984-07-11  /api/v1/people/8470794
# 925                C  1992-01-31  /api/v1/people/8475794
# 1074              RW  1993-06-17  /api/v1/people/8476453
# 1439               C  1997-01-13  /api/v1/people/8478402
# 568               LW  1989-07-18  /api/v1/people/8473994
# 412                C  1987-08-07  /api/v1/people/8471675
# 340                C  1986-07-31  /api/v1/people/8471215
# 907               RW  1991-12-13  /api/v1/people/8475765
# 619               RW  1988-11-19  /api/v1/people/8474141
# 762                C  1990-09-20  /api/v1/people/8475166
# 1456              RW  1997-02-25  /api/v1/people/8478444
# 652                C  1990-02-07  /api/v1/people/8474564
# 1520              RW  1998-04-19  /api/v1/people/8479339
# 1343              LW  1992-02-28  /api/v1/people/8477836
# 1576              RW  1994-05-19  /api/v1/people/8480330
# 844                D  1991-02-27  /api/v1/people/8475332
# 1517               C  1997-09-17  /api/v1/people/8479318
# 339               LW  1985-09-17  /api/v1/people/8471214
# 1403              LW  1996-04-01  /api/v1/people/8477998
# 1105               C  1993-07-25  /api/v1/people/8476511
# 1502               D  1996-10-10  /api/v1/people/8478915
# 874                D  1992-01-30  /api/v1/people/8475718
# 1166               D  1994-05-15  /api/v1/people/8476890
#
# [1581 rows x 8 columns]

# %% [markdown]
# ## Players Goals

# %%
Games_plays = pd.read_csv("../data/game_plays.csv")
Game_plays_players = pd.read_csv("../data/game_plays_players.csv")


Goals = pd.merge(Games_plays[(Games_plays['event'] == "Goal")],Game_plays_players[Game_plays_players['playerType'] == "Scorer"][['play_id','player_id']],on = 'play_id')

# %%
total_goals = pd.DataFrame(Goals.groupby(['player_id']).size())

# %%
Goals = pd.merge(Goals, PlayerInf[['player_id', 'firstName', 'lastName', 'primaryPosition', 'birthDate']], on = 'player_id')

# %%
Goals = pd.merge(Goals, Game[['season', 'game_id']], on = 'game_id')

# %%
total_goals =  pd.merge(total_goals, PlayerInf[['player_id', 'firstName', 'lastName', 'primaryPosition', 'birthDate']], on = 'player_id')
total_goals.sort_values(by=[0], ascending=False)
# Out:
#       player_id    0   firstName      lastName primaryPosition   birthDate
# 292     8471214  301        Alex      Ovechkin              LW  1985-09-17
# 354     8471675  232      Sidney        Crosby               C  1987-08-07
# 525     8474141  231     Patrick          Kane              RW  1988-11-19
# 277     8470794  222         Joe      Pavelski               C  1984-07-11
# 769     8475765  211    Vladimir     Tarasenko              RW  1991-12-13
# 649     8475166  204        John       Tavares               C  1990-09-20
# 785     8475794  198       Tyler        Seguin               C  1992-01-31
# 480     8473994  194       Jamie          Benn              LW  1989-07-18
# 293     8471215  194      Evgeni        Malkin               C  1986-07-31
# 250     8470621  193       Corey         Perry              RW  1985-05-16
# 416     8473419  191        Brad      Marchand              LW  1988-05-11
# 458     8473604  190    Jonathan         Toews               C  1988-04-29
# 556     8474564  189      Steven       Stamkos               C  1990-02-07
# 444     8473548  188        Phil        Kessel              RW  1987-10-02
# 500     8474053  187       Logan       Couture               C  1989-03-28
# 530     8474157  184         Max    Pacioretty              LW  1988-11-20
# 890     8476453  181      Nikita      Kucherov              RW  1993-06-17
# 369     8471707  179       James          Neal              LW  1987-09-03
# 238     8470604  177        Jeff        Carter               C  1985-01-01
# 46      8466139  175     Patrick       Marleau               C  1979-09-15
# 254     8470638  173     Patrice      Bergeron               C  1985-07-24
# 189     8470041  171        Rick          Nash              LW  1984-06-16
# 364     8471698  168        T.J.         Oshie              RW  1986-12-23
# 539     8474190  167       Wayne      Simmonds              RW  1988-08-26
# 242     8470610  163        Zach        Parise              LW  1984-07-28
# 495     8474037  162       James  van Riemsdyk              LW  1989-05-04
# 295     8471218  162       Blake       Wheeler              RW  1986-08-31
# 360     8471685  151        Anze       Kopitar               C  1987-08-24
# 651     8475168  151        Matt       Duchene               C  1991-01-16
# 778     8475784  150        Jeff       Skinner              LW  1992-05-16
# ...         ...  ...         ...           ...             ...         ...
# 570     8474582    1     Mattias       Tedenby              RW  1990-02-21
# 391     8471807    1         Tom       Wandell               C  1987-01-29
# 846     8476352    1     Michael        Mersch              LW  1992-10-02
# 274     8470774    1       Bruno       Gervais               D  1984-10-03
# 931     8476819    1      Jeremy         Welsh               C  1988-04-30
# 1183    8478454    1        Noah       Juulsen               D  1997-04-02
# 1182    8478451    1       Ethan          Bear               D  1997-06-26
# 403     8471912    1       Kevin     Henderson              LW  1986-12-03
# 748     8475733    1         Max      Reinhart               C  1992-02-04
# 404     8471916    1        Mike     Angelidis              LW  1985-06-27
# 549     8474516    1       Bryan          Lerg               C  1986-01-20
# 924     8476765    1        Mike         Halmo              LW  1991-05-15
# 756     8475749    1   Christian        Thomas              LW  1992-05-26
# 28      8462225    1       Filip          Kuba               D  1976-12-29
# 511     8474095    1        Dana        Tyrell               C  1989-04-23
# 918     8476511    1      Samuel        Henley               C  1993-07-25
# 1171    8478413    1      Jordan      Greenway              LW  1997-02-16
# 413     8472424    1        Ryan      Hamilton              LW  1985-04-15
# 170     8469608    1        Mike         Smith               G  1982-03-22
# 533     8474164    1    Jonathon          Blum               D  1989-01-30
# 771     8475767    1        Joey        Hishon               C  1991-10-20
# 181     8469765    1  Marc-Andre      Bergeron               D  1980-10-13
# 1162    8478376    1       Casey        Bailey              RW  1991-10-27
# 517     8474121    1      Colton       Gillies               C  1989-02-12
# 1159    8478146    1     Matthew      Highmore               C  1996-02-27
# 901     8476464    1      Duncan       Siemens               D  1993-09-07
# 11      8459687    1       Scott        Nichol               C  1974-12-31
# 1156    8478104    1       Sammy         Blais              LW  1996-06-17
# 185     8469820    1       Zenon       Konopka               C  1981-01-02
# 1011    8477210    1       Buddy      Robinson              RW  1991-09-30
#
# [1262 rows x 6 columns]

# %%
top_goaliers = total_goals.sort_values(by=[0], ascending=False)[:30]

# %%
Goals['distance'] = np.sqrt(np.power(Goals['st_x'] - 100+11,2)+np.power(Goals['st_y'],2))

# %%
Goals['periodType'].unique()
# Out:
# array(['REGULAR', 'OVERTIME', 'SHOOTOUT'], dtype=object)

# %%
def assist(s):
    s= s[s.find(':')+2:]
    s = s.split()
    if s[0] =='none':
        return("None")
    else:
        return(s[0]+' '+s[1])

def distance_bin(a):
    return("("+str((a//5)*5)+"ft, "+ str((a//5 + 1)*5) +"ft)")

# %%
Goals['assist'] = Goals['description'].apply(assist)

# %%
Goals['distance_bin'] = Goals['distance'].apply(distance_bin)
Goals['fullName'] = Goals['firstName']+ ' ' +Goals['lastName']

# %%
Goals['secondaryType'].unique()
# Out:
# array(['Slap Shot', 'Snap Shot', 'Tip-In', 'Wrist Shot', 'Backhand',
#        'Deflected', 'Wrap-around', nan], dtype=object)

# %%
for i in range(30):
    player_id  = int(top_goaliers.iloc[[i]]['player_id'])
    Goals[(Goals['player_id'] == player_id) & (Goals['st_x']>0)].to_csv("data/Players/" + str(player_id) + ".csv")
    pd.value_counts(Goals[(Goals['player_id'] == player_id) & (Goals['st_x']>0)]['distance_bin']).to_frame().reset_index().to_csv("data/Bars/" + str(player_id) + ".csv")
    print("<option value="+str(player_id)+">"+str(top_goaliers.iloc[i, 2])+' '+str(top_goaliers.iloc[i, 3])+"</option>")
# Out:
# <option value=8471214>Alex Ovechkin</option>
# <option value=8471675>Sidney Crosby</option>
# <option value=8474141>Patrick Kane</option>
# <option value=8470794>Joe Pavelski</option>
# <option value=8475765>Vladimir Tarasenko</option>
# <option value=8475166>John Tavares</option>
# <option value=8475794>Tyler Seguin</option>
# <option value=8473994>Jamie Benn</option>
# <option value=8471215>Evgeni Malkin</option>
# <option value=8470621>Corey Perry</option>
# <option value=8473419>Brad Marchand</option>
# <option value=8473604>Jonathan Toews</option>
# <option value=8474564>Steven Stamkos</option>
# <option value=8473548>Phil Kessel</option>
# <option value=8474053>Logan Couture</option>
# <option value=8474157>Max Pacioretty</option>
# <option value=8476453>Nikita Kucherov</option>
# <option value=8471707>James Neal</option>
# <option value=8470604>Jeff Carter</option>
# <option value=8466139>Patrick Marleau</option>
# <option value=8470638>Patrice Bergeron</option>
# <option value=8470041>Rick Nash</option>
# <option value=8471698>T.J. Oshie</option>
# <option value=8474190>Wayne Simmonds</option>
# <option value=8470610>Zach Parise</option>
# <option value=8474037>James van Riemsdyk</option>
# <option value=8471218>Blake Wheeler</option>
# <option value=8471685>Anze Kopitar</option>
# <option value=8475168>Matt Duchene</option>
# <option value=8475784>Jeff Skinner</option>

# %%
pd.value_counts(Goals['distance_bin']).to_frame().reset_index()
# Out:
#                  index  distance_bin
# 0     (10.0ft, 20.0ft)         13033
# 1      (0.0ft, 10.0ft)          7539
# 2     (20.0ft, 30.0ft)          6772
# 3     (30.0ft, 40.0ft)          4357
# 4     (40.0ft, 50.0ft)          2440
# 5     (50.0ft, 60.0ft)          1936
# 6   (160.0ft, 170.0ft)          1603
# 7   (170.0ft, 180.0ft)           979
# 8   (150.0ft, 160.0ft)           730
# 9     (60.0ft, 70.0ft)           584
# 10  (140.0ft, 150.0ft)           366
# 11  (130.0ft, 140.0ft)           243
# 12  (120.0ft, 130.0ft)           194
# 13    (70.0ft, 80.0ft)           136
# 14    (80.0ft, 90.0ft)           134
# 15   (90.0ft, 100.0ft)           124
# 16  (110.0ft, 120.0ft)            75
# 17  (100.0ft, 110.0ft)            58
# 18  (180.0ft, 190.0ft)            29
# 19      (nanft, nanft)            24

# %%
top_goaliers['fullName'] = top_goaliers['firstName']+ ' ' +top_goaliers['lastName']
top_goaliers[['player_id', 'fullName']].to_csv('data/Players/players.csv')

# %%
for i in range(30):
    print(str(top_goaliers.iloc[i, 0])+" : "+ "\'" + str(top_goaliers.iloc[i, 6])+"\',")
# Out:
# 8471214 : 'Alex Ovechkin',
# 8471675 : 'Sidney Crosby',
# 8474141 : 'Patrick Kane',
# 8470794 : 'Joe Pavelski',
# 8475765 : 'Vladimir Tarasenko',
# 8475166 : 'John Tavares',
# 8475794 : 'Tyler Seguin',
# 8473994 : 'Jamie Benn',
# 8471215 : 'Evgeni Malkin',
# 8470621 : 'Corey Perry',
# 8473419 : 'Brad Marchand',
# 8473604 : 'Jonathan Toews',
# 8474564 : 'Steven Stamkos',
# 8473548 : 'Phil Kessel',
# 8474053 : 'Logan Couture',
# 8474157 : 'Max Pacioretty',
# 8476453 : 'Nikita Kucherov',
# 8471707 : 'James Neal',
# 8470604 : 'Jeff Carter',
# 8466139 : 'Patrick Marleau',
# 8470638 : 'Patrice Bergeron',
# 8470041 : 'Rick Nash',
# 8471698 : 'T.J. Oshie',
# 8474190 : 'Wayne Simmonds',
# 8470610 : 'Zach Parise',
# 8474037 : 'James van Riemsdyk',
# 8471218 : 'Blake Wheeler',
# 8471685 : 'Anze Kopitar',
# 8475168 : 'Matt Duchene',
# 8475784 : 'Jeff Skinner',

# %% [markdown]
# ### Костыли

# %%
arr = []
for i in range(30):
    arr.append(top_goaliers.iloc[i, 0])
arr
# Out:
# [8471214,
#  8471675,
#  8474141,
#  8470794,
#  8475765,
#  8475166,
#  8475794,
#  8473994,
#  8471215,
#  8470621,
#  8473419,
#  8473604,
#  8474564,
#  8473548,
#  8474053,
#  8474157,
#  8476453,
#  8471707,
#  8470604,
#  8466139,
#  8470638,
#  8470041,
#  8471698,
#  8474190,
#  8470610,
#  8474037,
#  8471218,
#  8471685,
#  8475168,
#  8475784]

# %%
def GoalLocations(name, lastname):
    x,y = np.array(Goals[(Goals['lastName'] == lastname) & (Goals['firstName'] == name)]['st_x']),\
        np.array(Goals[(Goals['lastName'] == lastname) & (Goals['firstName'] == name)]['st_x'])
    return x,y

# %%
Goals[Goals['player_id'].isin(arr)].to_excel("data/General/Goals.xls")

# %%
Goals[(Goals['lastName'] == 'Ovechkin') & (Goals['firstName'] == 'Alex')].to_csv('goals.csv')

# %%
sns.distplot(Goals[(Goals['lastName'] == 'Ovechkin') & (Goals['firstName'] == 'Alex')]['distance'])

# %%
ax = sns.distplot(Goals[(Goals['lastName'] == 'Crosby') & (Goals['firstName'] == 'Sidney')]['distance'])
fig = ax.get_figure()
fig.savefig('demo.png', dpi = 500)

# %%
for i in range(30):
    player_id  = int(top_goaliers.iloc[[i]]['player_id'])
    fig = sns.distplot(Goals[Goals['player_id'] == player_id]['distance']).get_figure()
    fig.savefig("data/Bars/" + str(player_id) + ".png", dpi = 500)

# %%
ax = sns.scatterplot(x="distance", y="periodTimeRemaining", data=Goals[(Goals['lastName'] == 'Crosby') & (Goals['firstName'] == 'Sidney')])
